# %% [markdown]
# # \[R Shiny\]Cars
#
# SEOYEON CHOI
# 2025-09-16
#
# ## cars
#
# -   [link](https://seoyeonchoi.shinyapps.io/cars/)
# -   [data](https://www.kaggle.com/datasets/jockeroika/cars-dataset)
#
# [mermaid
# live](https://mermaid.live/edit#pako:eNqlVW1v2jAQ_iuRP1MUIG_kWwTZFhW2LrBKm5AiLzmCtcTOHKcdpfz3mQQqQgzSVn9J7Ofu_Nz5OXuHYpYActGKAp8SnHKcr6gmx8QL51-m_kzbNfPDePTCyScv1HLpk0Uk0R7uu-BPjmkSUZzDNcc2FnxealvAPCJUcJZUMSQNuG8-C2_mL1QsSpxBeY3FG8UP992t2isVJaKMSpYl3TAcUsJoi89DGEx8FZ-CkxjeyWfqT4K5N9NA1mIbZfAkneq4LQrLMJirGAhO8n8i0HJUHxnQlFCIxLa4DpbkBbo5lJBlhKYK_t700Q-XwcKf-7ICikRw8v9pXGBTb-kf4iVYKBKoSpBahWeFuiR7OIhyzbpgxmIsLoUhk_6oFAbJcfpeYZzMY5axSrH-ROC5YLKFutCaZFBgsemS_frNmwXL7zc5X9L6XeGMiG1UxoyDqgkgIbGQVb1gJPe9uFheX-_u2O7Y3662waXaoGm4GwZ1O9zAm4M5M6gdjmBbi2dGjdd5iFO5jkaoh1JOEuQKXkEP5cBzfJiiupwrJDYgGwq58jfB_NdK3rF76VNg-oOx_OTGWZVukLvGWSlnVXHQ6fEifjMBmgCfsIoK5Np1BOTu0B_kmrrRH40NQ3cs2x5b4x7aIndgWv2BY9iOqVvDkWOOjH0PvdRb6n3L0YdDwzJt3XTsgen0kDwvwfi8eQbq12D_F0bYuKg)
#
# ``` mermaid
# erDiagram
#     CARMODEL {
#         VARCHAR model_id PK
#         VARCHAR brand_name
#         VARCHAR model_name
#         INT year_introduced
#     }
#     SALES {
#         VARCHAR sales_id PK
#         VARCHAR model_id FK
#         INT year
#         INT units_sold
#         VARCHAR region
#     }
#     PRICE {
#         VARCHAR price_id PK
#         VARCHAR model_id FK
#         INT year
#         DECIMAL entry_level_price
#     }
#     TRIM {
#         VARCHAR trim_id PK
#         VARCHAR model_id FK
#         VARCHAR trim_name
#         VARCHAR engine_type
#         VARCHAR engine_size
#         DECIMAL selling_price
#     }
#     ADVERTISEMENT {
#         VARCHAR ad_id PK
#         VARCHAR model_id FK
#         VARCHAR trim_id FK
#         DATE ad_date
#         VARCHAR used_new
#         VARCHAR seller_info
#         VARCHAR location
#     }
#     IMAGE {
#         VARCHAR image_id PK
#         VARCHAR model_id FK
#         INT year
#         VARCHAR colour
#         VARCHAR viewpoint
#         VARCHAR filepath
#     }
#     IMAGEQUALITY {
#         VARCHAR image_id FK
#         INT quality_score
#         VARCHAR predicted_viewpoint
#     }
#
#     CARMODEL ||--o{ SALES : has
#     CARMODEL ||--o{ PRICE : has
#     CARMODEL ||--o{ TRIM : has
#     CARMODEL ||--o{ IMAGE : has
#     TRIM ||--o{ ADVERTISEMENT : has
#     IMAGE ||--o{ IMAGEQUALITY : has
# ```
