# %% [raw]
# ---
# title: "[Kaggle] Heart Disease Cleveland"
# author: "SEOYEON CHOI"
# date: "2025-12-01"
# ---

# %% [markdown]
# [data](https://www.kaggle.com/datasets/ritwikb3/heart-disease-cleveland)

# %%
df = pd.read_csv('../../../delete/spambase_csv.csv')
